# %% [markdown]
# <a href="https://colab.research.google.com/github/venkat-nallapu09/prediction-of-SWCC/blob/main/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784' , version = 1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x, y = mnist["data"], mnist["target"]
x.shape
# Out:
# (70000, 784)

# %%
y.shape
# Out:
# (70000,)

# %%
some_digit = x.iloc[10]
some_digit_image = some_digit.values.reshape(28, 28)

# %%
plt.imshow(some_digit_image)
plt.show()

# %%
y[10]
# Out:
# '3'

# %%
y.astype(int)
# Out:
# 0        5
# 1        0
# 2        4
# 3        1
# 4        9
#         ..
# 69995    2
# 69996    3
# 69997    4
# 69998    5
# 69999    6
# Name: class, Length: 70000, dtype: int64

# %%
X_train, X_test, y_train, y_test = x[:60000], x[60000:], y[:60000], y[60000:]

# %%
y_train_5 = (y_train == '5') # True for all 5s, False for all other digits
y_test_5 = (y_test == '5')

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train_5.astype(int))
# Out:
# SGDClassifier(random_state=42)

# %%
sgd_clf.predict([some_digit])
# Out:
# array([0])
